# %%
# !pip install pandas 
import pandas as pd
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
data={'Name': ['Alice', 'Bob', 'Charlie'],
'Age': [25, 30, 35],
'City': ['New York', 'Los Angeles',
'Chicago']}


df=pd.DataFrame(data)

# %%
print(df)
# Out:
#       Name  Age         City
# 0    Alice   25     New York
# 1      Bob   30  Los Angeles
# 2  Charlie   35      Chicago

# %%
print(df['City'])
# Out:
# 0       New York
# 1    Los Angeles
# 2        Chicago
# Name: City, dtype: object

# %%
print(df.iloc[1,1])
# Out:
# 30

# %%
print("new message is typed")

# %%
checkout ka msg dala hai
